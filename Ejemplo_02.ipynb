# %% [markdown]
# # Título

# %% [markdown]
# ## Subtítulo 1

# %% [markdown]
# * Idea 1
# * Idea 2

# %%
1 * 3
# Out:
# 3

# %%
70 % 2
# Out:
# 0

# %%
print("Hola, persona superinteresante que está viendo este vídeo")
# Out:
# Hola, persona superinteresante que está viendo este vídeo

# %%
a = 5
b = 6
print(a + b)
# Out:
# 11

# %%
nombre = "Nanci"
apellido = "Estevan"
print(f"El hobby preferido de {nombre} {apellido} es comer")
# Out:
# El hobby preferido de Nanci Estevan es comer

# %%
nombre = input("¿Cómo se llama?")
print(f"Hola, {nombre}")
# Out:
# ¿Cómo se llama? Rosa
# Hola, Rosa

# %% [markdown]
# ### Elemento multimedia

# %% [markdown]
# ![MecanismoDeAnticitera.jpg](attachment:14b92b08-47b4-406a-a439-d3f33c712383.jpg)

# %%
import pandas as pd

tabla = pd.DataFrame(data = [[1,1], [2,4], [3,9]],
                    columns = ["numero", "cuadrado"])

tabla
# Out:
#    numero  cuadrado
# 0       1         1
# 1       2         4
# 2       3         9
